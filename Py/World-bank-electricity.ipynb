# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Reading Json File using dataframe

# %%
df=pd.read_json(r"C:\Users\supri\Downloads\world_bank_electricity_report-20221201T083621Z-001\world_bank_electricity_report\electricity_production_nuclear_sources\API_EG.ELC.NUCL.ZS_DS2_en_csv_v2_4357319.json")

# %%
df
# Out:
#                               0             1   \
# 0              Last Updated Date    2022-07-20
# 1                   Country Name  Country Code
# 2                          Aruba           ABW
# 3    Africa Eastern and Southern           AFE
# 4                    Afghanistan           AFG
# ..                           ...           ...
# 263                       Kosovo           XKX
# 264                  Yemen, Rep.           YEM
# 265                 South Africa           ZAF
# 266                       Zambia           ZMB
# 267                     Zimbabwe           ZWE
#
#                                                     2               3     4   \
# 0
# 1                                       Indicator Name  Indicator Code  1960
# 2    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS
# 3    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS
# 4    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS
# ...

# %% [markdown]
# ### Dropping 0th row

# %%
df=df.drop(0)
df
# Out:
#                               0             1   \
# 1                   Country Name  Country Code
# 2                          Aruba           ABW
# 3    Africa Eastern and Southern           AFE
# 4                    Afghanistan           AFG
# 5     Africa Western and Central           AFW
# ..                           ...           ...
# 263                       Kosovo           XKX
# 264                  Yemen, Rep.           YEM
# 265                 South Africa           ZAF
# 266                       Zambia           ZMB
# 267                     Zimbabwe           ZWE
#
#                                                     2               3     4   \
# 1                                       Indicator Name  Indicator Code  1960
# 2    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS
# 3    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS
# 4    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS
# ...

# %% [markdown]
# ### Droping 66th Column

# %%
df=df.drop([66],axis=1)
df
# Out:
#                               0             1   \
# 1                   Country Name  Country Code
# 2                          Aruba           ABW
# 3    Africa Eastern and Southern           AFE
# 4                    Afghanistan           AFG
# 5     Africa Western and Central           AFW
# ..                           ...           ...
# 263                       Kosovo           XKX
# 264                  Yemen, Rep.           YEM
# 265                 South Africa           ZAF
# 266                       Zambia           ZMB
# 267                     Zimbabwe           ZWE
#
#                                                     2               3     4   \
# 1                                       Indicator Name  Indicator Code  1960
# 2    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS
# 3    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS
# 4    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS
# ...

# %% [markdown]
# ### Replacing empty value with Null

# %%
df.replace('',np.nan, inplace=True)
df
# Out:
#                               0             1   \
# 1                   Country Name  Country Code
# 2                          Aruba           ABW
# 3    Africa Eastern and Southern           AFE
# 4                    Afghanistan           AFG
# 5     Africa Western and Central           AFW
# ..                           ...           ...
# 263                       Kosovo           XKX
# 264                  Yemen, Rep.           YEM
# 265                 South Africa           ZAF
# 266                       Zambia           ZMB
# 267                     Zimbabwe           ZWE
#
#                                                     2               3     4   \
# 1                                       Indicator Name  Indicator Code  1960
# 2    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS   NaN
# 3    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS   NaN
# 4    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS   NaN
# ...

# %% [markdown]
# ### Converting Datatype

# %%
df.dtypes
# Out:
# 0      object
# 1      object
# 2      object
# 3      object
# 4      object
#        ...
# 61    float64
# 62    float64
# 63    float64
# 64    float64
# 65    float64
# Length: 66, dtype: object

# %%
for i in df.columns:
    df[i]=pd.to_numeric(df[i],errors='ignore')

# %%
df.dtypes
# Out:
# 0      object
# 1      object
# 2      object
# 3      object
# 4     float64
#        ...
# 61    float64
# 62    float64
# 63    float64
# 64    float64
# 65    float64
# Length: 66, dtype: object

# %% [markdown]
# ### Assigning new Column heading

# %%
new_header=df.iloc[0]
df=df[1:]
df.columns=new_header
df
# Out:
# 1                   Country Name Country Code  \
# 2                          Aruba          ABW
# 3    Africa Eastern and Southern          AFE
# 4                    Afghanistan          AFG
# 5     Africa Western and Central          AFW
# 6                         Angola          AGO
# ..                           ...          ...
# 263                       Kosovo          XKX
# 264                  Yemen, Rep.          YEM
# 265                 South Africa          ZAF
# 266                       Zambia          ZMB
# 267                     Zimbabwe          ZWE
#
# 1                                       Indicator Name  Indicator Code  \
# 2    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS
# 3    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS
# 4    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS
# 5    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS
# ...

# %%
df["Indicator Name"]=df["Indicator Name"].str.replace(",","")
df
# Out:
# C:\Users\supri\AppData\Local\Temp\ipykernel_18644\1863543918.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Indicator Name"]=df["Indicator Name"].str.replace(",","")
# 1                   Country Name Country Code  \
# 2                          Aruba          ABW
# 3    Africa Eastern and Southern          AFE
# 4                    Afghanistan          AFG
# 5     Africa Western and Central          AFW
# 6                         Angola          AGO
# ..                           ...          ...
# 263                       Kosovo          XKX
# 264                  Yemen, Rep.          YEM
# 265                 South Africa          ZAF
# 266                       Zambia          ZMB
# ...

# %%
df.dtypes
# Out:
# 1
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960.0            float64
#                    ...
# 2017.0            float64
# 2018.0            float64
# 2019.0            float64
# 2020.0            float64
# 2021.0            float64
# Length: 66, dtype: object

# %% [markdown]
# ### Saving it to Csv File

# %%
df.to_csv(r"C:\Users\supri\Downloads\OUTPUT\CSV\electricity_production_nuclear_sources.csv", index=False)

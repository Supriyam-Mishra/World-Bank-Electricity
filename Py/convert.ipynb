# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\supri\Downloads\OUTPUT\CSV\electricity_production_nuclear_sources.csv")

# %%
df
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  1960  \
# 0    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS   NaN
# 1    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS   NaN
# 2    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS   NaN
# 3    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS   NaN
# ...

# %%
df.columns = ['_' + str(col) for col in df.columns]

# %%
df
# Out:
#                    _Country Name _Country Code  \
# 0                          Aruba           ABW
# 1    Africa Eastern and Southern           AFE
# 2                    Afghanistan           AFG
# 3     Africa Western and Central           AFW
# 4                         Angola           AGO
# ..                           ...           ...
# 261                       Kosovo           XKX
# 262                  Yemen, Rep.           YEM
# 263                 South Africa           ZAF
# 264                       Zambia           ZMB
# 265                     Zimbabwe           ZWE
#
#                                        _Indicator Name _Indicator Code  _1960  \
# 0    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS    NaN
# 1    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS    NaN
# 2    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS    NaN
# 3    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS    NaN
# ...

# %%
df.rename(columns = {'_Country Name':'Country_Name','_Country Code':'Country_Code','_Indicator Name':'Indicator_Name' ,'_Indicator Code':'Indicator_Code'}, inplace=True)

# %%
df
# Out:
#                     Country_Name Country_Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator_Name  Indicator_Code  _1960  \
# 0    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS    NaN
# 1    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS    NaN
# 2    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS    NaN
# 3    Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS    NaN
# ...

# %%
df.to_csv(r"C:\Users\supri\Downloads\OUTPUT\CSV\Nuclear.csv", index=False)
